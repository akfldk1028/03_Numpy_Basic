# %% [markdown]
# # from Random Distributions

# %% [markdown]
# ## from Normal Distributions

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
# plt.style.use('seaborn')
fig, ax = plt.subplots(figsize=(10, 5))
random_values = np.random.randn(3000)
ax.hist(random_values, bins=50)
print(random_values.shape)
# Out:
# (3000,)

# %%
import numpy as np
normal1 = np.random.normal(loc=-2, scale=1, size=(200, ))
normal2 = np.random.normal(loc=0, scale=2, size=(200, ))
normal3 = np.random.normal(loc=3, scale=5, size=(200, ))

# %%
normal = np.random.normal(loc=[-2, 0, 3],
 scale=[1, 2, 5],
 size=(200, 3))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
normal = np.random.normal(loc=-2, scale=1, size=(3, 3))
print(normal)
# Out:
# [[-2.13210317 -2.71107565 -1.48819945]
#  [-3.2575575  -2.36615191 -2.15133344]
#  [-4.08273468 -2.47221026 -1.73089651]]

# %% [markdown]
# ## from Uniform Distributions

# %% [markdown]
# - random.rand(d0, d1, ..., dn)
# - random.uniform(low=0.0, high=1.0, size=None)
# - random.randint(low, high=None, size=None, dtype=int)

# %%
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10, 5))
# 1000개의 datasampling 을 uniform distribution 으로 부터 생성합니다.
uniform = np.random.rand(1000)
ax.hist(uniform)
print(uniform.shape)
# Out:
# (1000,)

# %%
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10, 5))
# 1000개의 datasampling 을 uniform distribution 으로 부터 생성합니다.
uniform = np.random.rand(100,100)
ax.hist(uniform)
# ax.hist(uniform.flatten())
print(uniform.shape)
# Out:
# (100, 100)

# %%
import numpy as np
(2, 3, 4)
uniform = np.random.rand(2, 3, 4)
# ax.hist(uniform)

print(uniform.shape)
# Out:
# (2, 3, 4)

# %%
import numpy as np
import matplotlib.pyplot as plt
# plt.style.use(‘seaborn')
fig, ax = plt.subplots(figsize=(10, 5))
uniform = np.random.uniform(low=-10, high=10, size=(100, ))
ax.hist(uniform, bins=20)
# Out:
# (array([ 4.,  5.,  2.,  7.,  5.,  5.,  3.,  3.,  6.,  6., 11.,  8.,  5.,
#          5.,  2.,  2.,  3.,  4.,  7.,  7.]),
#  array([-9.9174484 , -8.92427397, -7.93109953, -6.93792509, -5.94475066,
#         -4.95157622, -3.95840178, -2.96522735, -1.97205291, -0.97887848,
#          0.01429596,  1.0074704 ,  2.00064483,  2.99381927,  3.98699371,
#          4.98016814,  5.97334258,  6.96651702,  7.95969145,  8.95286589,
#          9.94604033]),
#  <BarContainer object of 20 artists>)

# %%
import numpy as np
randint = np.random.randint(low=0, high=7, size=(20, ))
print(randint)
# Out:
# [2 0 4 2 4 6 4 3 4 1 3 4 3 2 2 6 3 4 3 4]
